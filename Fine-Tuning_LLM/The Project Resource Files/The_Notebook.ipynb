# %% [markdown]
# # Welcome To The Notebook

# %% [markdown]
# ### Task 1 - Set up the project environment

# %%
# !pip install openai==1.7.2 python-dotenv

# %% [markdown]
# Importing modules

# %%
import pandas as pd
import os, time
from openai import OpenAI
from dotenv import load_dotenv
import json
import matplotlib.pyplot as plt

print("Modules are imported.")
# Out:
# Modules are imported.

# %%
from dotenv import load_dotenv

load_dotenv()
OPENAI_API_TOKEN = os.getenv("OPENAI_API_TOKEN")

# %% [markdown]
# Creating OpenAI Client

# %%
client =  OpenAI(api_key=OPENAI_API_TOKEN)
client

# %% [markdown]
# ### Task 2 - Prepare the training data

# %% [markdown]
# Loading the provided `Customer Complaints.csv`

# %%
df = pd.read_csv("Customer Complaints.csv")
df['Details']
# Out:
# 0     {"Topic": "Internet", "Problem": "Unreliable s...
# 1     {"Topic": "TV", "Problem": "Signal dropout", "...
# 2     {"Topic": "Phone", "Problem": "Crackling line"...
# 3     {"Topic": "Billing", "Problem": "Overcharged",...
# 4     {"Topic": "Internet", "Problem": "Slow speed",...
#                             ...
# 62    {"Topic": "Phone", "Problem": "Poor call quali...
# 63    {"Topic": "Billing", "Problem": "Incorrect cha...
# 64    {"Topic": "PulseNet General", "Problem": "Gene...
# 65    {"Topic": "PulseNet General", "Problem": "Gene...
# 66    {"Topic": "PulseNet General", "Problem": "Gene...
# Name: Details, Length: 67, dtype: object

# %% [markdown]
# **Converting the Complaints records to json**
#
# To be able to use the data for the fine-tuning purpose, we first need to convert each row of the dataframe into the following format:
#
# <pre>
# <code>
# {
#   <span style="color: blue;">"messages"</span>: [
#     {
#       <span style="color: blue;">"role"</span>: <span style="color: red;">"system"</span>,
#       <span style="color: blue;">"content"</span>: "<span style="color: green;">Providing context about the user's prompt.
#                   It may include information about the task,
#                   instructions, or background details relevant
#                   to the conversation.</span>"
#     },
#     {
#       <span style="color: blue;">"role"</span>: <span style="color: red;">"user"</span>,
#       <span style="color: blue;">"content"</span>: "<span style="color: green;">the prompt or input provided by the user,
#                   which typically initiates the conversation with the assistant.</span>"
#     },
#     {
#       <span style="color: blue;">"role"</span>: <span style="color: red;">"assistant"</span>,
#       <span style="color: blue;">"content"</span>: "<span style="color: green;">The desired response or output generated by
#                   the assistant in response to the user's prompt.</span>"
#     }
#   ]
# }
# </code>
# </pre>
#
# Let's get started!

# %% [markdown]
# Let's define a method that get's a row of the dataframe and convert it into the json format

# %%
def save_as_json(row):

  system_content = """
      Given a customer complaint text, extract and return the following information in json (dict) format:
      - Topic: The product/department that the customer has a complaint about.
      - Problem: A two or three-word description of what exactly the problem is.
      - Customer_Dissatisfaction_Index: is a number between 0 and 100 showing
             how angry the customer is about the problem.
  """

  formatted_data = {
        "messages": [
            {"role": "system", "content": system_content},
            {"role": "user", "content": row.Complaints},
            {"role": "assistant", "content": row.Details}
        ]
      }

  with open("training_data.jsonl", "a") as json_file:
        json.dump(formatted_data, json_file)
        json_file.write("\n")

# %% [markdown]
# Now let's use of this method to generate the `training_data.json`

# %%
for index,row in df.iterrows():
    save_as_json(row)

# %% [markdown]
# ### Task 3 - Fine-tune GPT 4 mini based on our training data

# %% [markdown]
# Let's import the json file we prepared as our training data

# %%
data_file = client.files.create(
    file = open("training_data.jsonl", "rb"),
    purpose= "fine-tune",
    )
data_file
# Out:
# FileObject(id='file-5nJQLXozQP12N5tiRrdBoe', bytes=46722, created_at=1732808072, filename='training_data.jsonl', object='file', purpose='fine-tune', status='processed', status_details=None)

# %% [markdown]
# Create the Fine Tuning Job

# %%
fine_tuning_job = client.fine_tuning.jobs.create(
    training_file=data_file.id, 
    model = "gpt-4o-mini-2024-07-18",
    hyperparameters={
        "n_epochs": "auto"
        }
    )

# %%
fine_tuning_job
# Out:
# FineTuningJob(id='ftjob-sC8rpU5j9nyOltsZfbSEjBMR', created_at=1732811047, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-Lqzv96QnFH3JDxxzx5j84wxT', result_files=[], seed=317319951, status='validating_files', trained_tokens=None, training_file='file-5nJQLXozQP12N5tiRrdBoe', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix=None)

# %% [markdown]
# Let's retrieve the state of the fine-tune

# %%
while True:
    time.sleep(2)
    retrieve_job = client.fine_tuning.jobs.retrieve(fine_tuning_job.id)
    status = retrieve_job.status
    print(status)

    if (status == 'succeeded'):
        print('Done!')
        break
# Out:
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# running
# succeeded
# Done!

# %% [markdown]
# ### Task 4 - Evaluate model

# %% [markdown]
# Let's retrieve the event messages to check out the learning process of our fine-tuning job.

# %%
client.fine_tuning.jobs.list_events(fine_tuning_job_id=retrieve_job.id, limit = 100).data
# Out:
# [FineTuningJobEvent(id='ftevent-LjtaupHeJ2UN49u0QEFwimP2', created_at=1732811515, level='info', message='The job has successfully completed', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-HK8TFDYgTEPxVVwG9ODZc9y1', created_at=1732811510, level='info', message='New fine-tuned model created', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-iUUHJ1EcNvcr9qy5XwRkzu8g', created_at=1732811510, level='info', message='Checkpoint created at step 134', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-zpi5dDBjbaETd8xFc7IKU0jx', created_at=1732811510, level='info', message='Checkpoint created at step 67', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-h1geSMS6Crg43QC8OQ4lLpnz', created_at=1732811491, level='info', message='Step 201/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 201, 'train_loss': 9.646782564232126e-05, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-ZJXE1fdN4bMSMurGNirUJlyL', created_at=1732811466, level='info', message='Step 200/201: training loss=0.17', object='fine_tuning.job.event', data={'step': 200, 'train_loss': 0.17031258344650269, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-Wpo5MyTF2PrpKLRtX24BSURM', created_at=1732811463, level='info', message='Step 199/201: training loss=0.12', object='fine_tuning.job.event', data={'step': 199, 'train_loss': 0.121199831366539, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-y6lRBz0VyemA8J74sHUwhCXi', created_at=1732811463, level='info', message='Step 198/201: training loss=0.11', object='fine_tuning.job.event', data={'step': 198, 'train_loss': 0.10778088122606277, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-gVF7tvH5IZIapbOiXRq33ovy', created_at=1732811462, level='info', message='Step 197/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 197, 'train_loss': 0.040592193603515625, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-sZlPkhwCrYMVE5lAJ4vq17Dc', created_at=1732811458, level='info', message='Step 196/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 196, 'train_loss': 0.009552688337862492, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-zTwMdod49VUwaOXIdbybD3zc', created_at=1732811458, level='info', message='Step 195/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 195, 'train_loss': 0.07646164298057556, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-DyhUAZNEX5KsZcRncpvCxcqM', created_at=1732811458, level='info', message='Step 194/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 194, 'train_loss': 0.0001431978598702699, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-OK34pmnuHdquqwl4YdCXP1DS', created_at=1732811458, level='info', message='Step 193/201: training loss=0.12', object='fine_tuning.job.event', data={'step': 193, 'train_loss': 0.12042815238237381, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-WsWOES79g3gIjQBKplwlFeLH', created_at=1732811458, level='info', message='Step 192/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 192, 'train_loss': 0.04815402254462242, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-FFNbG2yuiMoCsEw29E7s55tA', created_at=1732811455, level='info', message='Step 191/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 191, 'train_loss': 0.011821134015917778, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-t8uH2YawZ1UxBsDyHrlCMdjG', created_at=1732811454, level='info', message='Step 190/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 190, 'train_loss': 0.08357106894254684, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-7XpYIRnm8EjsAseXHpuCyFbe', created_at=1732811454, level='info', message='Step 189/201: training loss=0.14', object='fine_tuning.job.event', data={'step': 189, 'train_loss': 0.14458230137825012, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-DUO4TuFpJr5oLcCS8sUAldbs', created_at=1732811454, level='info', message='Step 188/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 188, 'train_loss': 0.072931669652462, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-H22dosJ95xzcE1fVvHaH3Noz', created_at=1732811453, level='info', message='Step 187/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 187, 'train_loss': 0.027433065697550774, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-6U45wIP734qGu0MVZsO9zMuI', created_at=1732811448, level='info', message='Step 186/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 186, 'train_loss': 0.009787633083760738, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-RgiJuNN4R6bxfRNXpK8FN7u6', created_at=1732811448, level='info', message='Step 185/201: training loss=0.12', object='fine_tuning.job.event', data={'step': 185, 'train_loss': 0.12303062528371811, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-3QZyEI4eFzjApAJc3ECRxxJ2', created_at=1732811448, level='info', message='Step 184/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 184, 'train_loss': 0.010551986284554005, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-t9CJk0e2Rm0kKTHzRUhcAsFb', created_at=1732811448, level='info', message='Step 183/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 183, 'train_loss': 0.00011099301627837121, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-thYGvUj000pOmXe2nBI5p37d', created_at=1732811448, level='info', message='Step 182/201: training loss=0.10', object='fine_tuning.job.event', data={'step': 182, 'train_loss': 0.09549449384212494, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-zTFNQIMV3XIQN9ZisqRXA2tW', created_at=1732811444, level='info', message='Step 181/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 181, 'train_loss': 0.03159424290060997, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-WWCleOeLTFlImaA4G1amBmzF', created_at=1732811443, level='info', message='Step 180/201: training loss=0.11', object='fine_tuning.job.event', data={'step': 180, 'train_loss': 0.10855743288993835, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-Olcf6P5nfgvInpurGr8B3lOP', created_at=1732811442, level='info', message='Step 179/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 179, 'train_loss': 9.712806058814749e-05, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-PBgWbWRcZ29hL00K9IWgirRX', created_at=1732811439, level='info', message='Step 178/201: training loss=0.06', object='fine_tuning.job.event', data={'step': 178, 'train_loss': 0.06305423378944397, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-nEEYVDikU03ZxtxXGDMBRF0n', created_at=1732811439, level='info', message='Step 177/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 177, 'train_loss': 0.03794418275356293, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-HkAKdTIe2qNMSunwHuItWBuh', created_at=1732811439, level='info', message='Step 176/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 176, 'train_loss': 0.00019697043171618134, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-fBe5PhzSpVcgXKDPPb41ifCP', created_at=1732811439, level='info', message='Step 175/201: training loss=0.12', object='fine_tuning.job.event', data={'step': 175, 'train_loss': 0.1155158132314682, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-2ROJMHRfZ5XbHoqyBlfVk0pf', created_at=1732811439, level='info', message='Step 174/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 174, 'train_loss': 0.00958862341940403, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-cc5KR83mLhx3vNrxwlxYTLxU', created_at=1732811439, level='info', message='Step 173/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 173, 'train_loss': 0.02345537208020687, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-oAFOlsEB55QQgQsmmVaWd5fp', created_at=1732811435, level='info', message='Step 172/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 172, 'train_loss': 0.011686544865369797, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-OC7cqzE5unXj7Na9oDj8P7sU', created_at=1732811435, level='info', message='Step 171/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 171, 'train_loss': 0.01678473874926567, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-uoykNaDvVbgt0khJd1ezV88K', created_at=1732811433, level='info', message='Step 170/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 170, 'train_loss': 0.03141219541430473, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-hFQxmGjFTvNIqrvZH07v1sLM', created_at=1732811430, level='info', message='Step 169/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 169, 'train_loss': 0.01620635949075222, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-7MWJKPZrresPf035MVdHCwKl', created_at=1732811430, level='info', message='Step 168/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 168, 'train_loss': 0.048289377242326736, 'total_steps': 201, 'train_mean_token_accuracy': 0.9583333134651184}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-ageBPnQtue0lFZemNVCshTBp', created_at=1732811430, level='info', message='Step 167/201: training loss=0.14', object='fine_tuning.job.event', data={'step': 167, 'train_loss': 0.13864313066005707, 'total_steps': 201, 'train_mean_token_accuracy': 0.9259259104728699}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-FVPHk0mh0EHYJb5b9GAbYF5B', created_at=1732811430, level='info', message='Step 166/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 166, 'train_loss': 0.020195618271827698, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-e9zDanqoI6SlMrxsdNiEkfDz', created_at=1732811430, level='info', message='Step 165/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 165, 'train_loss': 0.0727560892701149, 'total_steps': 201, 'train_mean_token_accuracy': 0.9642857313156128}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-EqrkxaNOEs8x6Jjyvxwq5ftO', created_at=1732811426, level='info', message='Step 164/201: training loss=0.16', object='fine_tuning.job.event', data={'step': 164, 'train_loss': 0.15794624388217926, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-JG6BFnc5RpsYdBtz6PWgkgN3', created_at=1732811426, level='info', message='Step 163/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 163, 'train_loss': 0.03106219880282879, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-8LJDxyr9T3cqaFdPXxrMYWyV', created_at=1732811426, level='info', message='Step 162/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 162, 'train_loss': 0.03679070994257927, 'total_steps': 201, 'train_mean_token_accuracy': 0.9642857313156128}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-5wZb8ivj4bp8xI7Yx6ZM50Vn', created_at=1732811426, level='info', message='Step 161/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 161, 'train_loss': 0.03073738142848015, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-jlRC9pkkPXz76KbcnfsxPRfa', created_at=1732811425, level='info', message='Step 160/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 160, 'train_loss': 0.0790523961186409, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-59pwXXTc8fizHHv6c9rYfrBb', created_at=1732811424, level='info', message='Step 159/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 159, 'train_loss': 0.04883259907364845, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-DpjMqjxLrFl4RLQFaGGsTr9f', created_at=1732811421, level='info', message='Step 158/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 158, 'train_loss': 0.011707687750458717, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-RMwloLQizY94HfKYvlE2vSoW', created_at=1732811421, level='info', message='Step 157/201: training loss=0.06', object='fine_tuning.job.event', data={'step': 157, 'train_loss': 0.06235063821077347, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-Ue2Ql61KImlwrSJ3E9FzOGl4', created_at=1732811418, level='info', message='Step 156/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 156, 'train_loss': 0.03096771240234375, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-2vHlZNQerFloVBwraVCqPuht', created_at=1732811414, level='info', message='Step 155/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 155, 'train_loss': 0.017130661755800247, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-ofGKmxdahohSaLVNK7jG2QjL', created_at=1732811414, level='info', message='Step 154/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 154, 'train_loss': 0.019168930128216743, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-KnrNPhkgC6G821kHRfDbM0X4', created_at=1732811414, level='info', message='Step 153/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 153, 'train_loss': 0.00010710496280808002, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-cUC1VxCca666cXZVSaLJtlx0', created_at=1732811414, level='info', message='Step 152/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 152, 'train_loss': 0.07293672114610672, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-rdrOK3Zs3b1YAPiA0UfqKDjP', created_at=1732811414, level='info', message='Step 151/201: training loss=0.01', object='fine_tuning.job.event', data={'step': 151, 'train_loss': 0.013473374769091606, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-COEgHmGtM7lm1xIDy6s37OMb', created_at=1732811410, level='info', message='Step 150/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 150, 'train_loss': 0.06598211079835892, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-WrNO6QTOtJ9qw4RgPlkcE2rC', created_at=1732811410, level='info', message='Step 149/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 149, 'train_loss': 0.06537400931119919, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-2U7oQJ49B44LWbCPY2sdJcbq', created_at=1732811409, level='info', message='Step 148/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 148, 'train_loss': 0.00012507804785855114, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-FEaHk0MKfe8GzzwUoE4n2C8v', created_at=1732811405, level='info', message='Step 147/201: training loss=0.21', object='fine_tuning.job.event', data={'step': 147, 'train_loss': 0.20979399979114532, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-3wUdjZZ82GTza2o36wZ6c7Mv', created_at=1732811405, level='info', message='Step 146/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 146, 'train_loss': 0.0002840482338797301, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-B2knvkoh4guQJoWTbcyiVMkB', created_at=1732811405, level='info', message='Step 145/201: training loss=0.10', object='fine_tuning.job.event', data={'step': 145, 'train_loss': 0.09986606240272522, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-BJumMe21769utlp5dXNYTrVK', created_at=1732811405, level='info', message='Step 144/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 144, 'train_loss': 0.01757972687482834, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-Q9zCXijuSKcd2GITnzdcGxe7', created_at=1732811405, level='info', message='Step 143/201: training loss=0.12', object='fine_tuning.job.event', data={'step': 143, 'train_loss': 0.1230965405702591, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-1gAQwFk4K85SNUunDNKDRFvN', created_at=1732811402, level='info', message='Step 142/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 142, 'train_loss': 0.03335985541343689, 'total_steps': 201, 'train_mean_token_accuracy': 0.9655172228813171}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-4JX8dizDiOOqIZ4obXV1tuj0', created_at=1732811402, level='info', message='Step 141/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 141, 'train_loss': 0.08370678126811981, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-WqelK539Ypv985y5oGUUrmTj', created_at=1732811401, level='info', message='Step 140/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 140, 'train_loss': 0.03515949845314026, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-oROhUWDRPkYxED59iQcu8ToN', created_at=1732811400, level='info', message='Step 139/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 139, 'train_loss': 0.03470216318964958, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-g4QNNc8pBjVgq6NPKHn5eAEO', created_at=1732811396, level='info', message='Step 138/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 138, 'train_loss': 0.03811704367399216, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-QOPRh6CE8E0ymezMcTXPNHOv', created_at=1732811396, level='info', message='Step 137/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 137, 'train_loss': 0.0510115809738636, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-RwyDxaGqtGnm3BP0LuYk6kfQ', created_at=1732811396, level='info', message='Step 136/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 136, 'train_loss': 0.0015368828317150474, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-orOvXzhAsm4M30j69T5yc32e', created_at=1732811396, level='info', message='Step 135/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 135, 'train_loss': 0.051634445786476135, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-yZ1mJ8mdP2MG7rrXzF4VrNoa', created_at=1732811392, level='info', message='Step 134/201: training loss=0.17', object='fine_tuning.job.event', data={'step': 134, 'train_loss': 0.1679488718509674, 'total_steps': 201, 'train_mean_token_accuracy': 0.9230769276618958}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-gGBwjfvFsWtYKU08lsBlIki3', created_at=1732811365, level='info', message='Step 133/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 133, 'train_loss': 0.048895396292209625, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-S2BgGQxwQYt6FxogejU4hZNj', created_at=1732811365, level='info', message='Step 132/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 132, 'train_loss': 0.028892870992422104, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-pxHj99sGRZLA0CcvUZriYloN', created_at=1732811364, level='info', message='Step 131/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 131, 'train_loss': 0.04058683663606644, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-mHGeN8qCD9xM4POizr1cDGs4', created_at=1732811359, level='info', message='Step 130/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 130, 'train_loss': 0.052592549473047256, 'total_steps': 201, 'train_mean_token_accuracy': 0.9642857313156128}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-AiM1qQyuaxAWk1bjz4d0gRfk', created_at=1732811359, level='info', message='Step 129/201: training loss=0.05', object='fine_tuning.job.event', data={'step': 129, 'train_loss': 0.05057801306247711, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-TARu2RUjxxOicEdKkTrqQPni', created_at=1732811359, level='info', message='Step 128/201: training loss=0.06', object='fine_tuning.job.event', data={'step': 128, 'train_loss': 0.056243896484375, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-rbTSNNyVsV3JD9351oaVqXjV', created_at=1732811359, level='info', message='Step 127/201: training loss=0.15', object='fine_tuning.job.event', data={'step': 127, 'train_loss': 0.1466524451971054, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-8Xge5QGVHHquW5gubjzayATU', created_at=1732811356, level='info', message='Step 126/201: training loss=0.09', object='fine_tuning.job.event', data={'step': 126, 'train_loss': 0.09144844114780426, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-8mqvAVcPnZr75iMDJFPJfAHc', created_at=1732811356, level='info', message='Step 125/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 125, 'train_loss': 0.07737571746110916, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-jQHwbiKG6KBOpgaeMfE5avKl', created_at=1732811356, level='info', message='Step 124/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 124, 'train_loss': 0.0003639367932919413, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-5sd8GZyKCmcfxCsDxbeksgMT', created_at=1732811356, level='info', message='Step 123/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 123, 'train_loss': 0.0003698789223562926, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-PdRzn3Z2jlXx0mP3GLX6xO13', created_at=1732811356, level='info', message='Step 122/201: training loss=0.06', object='fine_tuning.job.event', data={'step': 122, 'train_loss': 0.06358234584331512, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-mV2lREuPutKqjOff8NwfuoER', created_at=1732811354, level='info', message='Step 121/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 121, 'train_loss': 0.020333783701062202, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-hv0uYPJtbbXq2Nmj1X8eHfVX', created_at=1732811348, level='info', message='Step 120/201: training loss=0.04', object='fine_tuning.job.event', data={'step': 120, 'train_loss': 0.04143333435058594, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-fPSHKblDRt9KvRSEvzFTsfPB', created_at=1732811348, level='info', message='Step 119/201: training loss=0.09', object='fine_tuning.job.event', data={'step': 119, 'train_loss': 0.08863776177167892, 'total_steps': 201, 'train_mean_token_accuracy': 0.9642857313156128}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-kUNBbAHPvZoTLOSBrveo6Bnu', created_at=1732811348, level='info', message='Step 118/201: training loss=0.09', object='fine_tuning.job.event', data={'step': 118, 'train_loss': 0.08826426416635513, 'total_steps': 201, 'train_mean_token_accuracy': 0.9642857313156128}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-UQDaDDrwzPN4lL5843z4hTx7', created_at=1732811348, level='info', message='Step 117/201: training loss=0.11', object='fine_tuning.job.event', data={'step': 117, 'train_loss': 0.11495011299848557, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-fjCj8fjlVvKU73lG5rzn9O32', created_at=1732811345, level='info', message='Step 116/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 116, 'train_loss': 0.001233394374139607, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-g8msQy9MsTi3OqJSZ44iuGoY', created_at=1732811345, level='info', message='Step 115/201: training loss=0.03', object='fine_tuning.job.event', data={'step': 115, 'train_loss': 0.027672426775097847, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-MiUq84SfGG3IbhEhZ2ZIDQQW', created_at=1732811345, level='info', message='Step 114/201: training loss=0.06', object='fine_tuning.job.event', data={'step': 114, 'train_loss': 0.06319364160299301, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-QjqyWD5cR655pqksEAFooWLu', created_at=1732811344, level='info', message='Step 113/201: training loss=0.13', object='fine_tuning.job.event', data={'step': 113, 'train_loss': 0.1261758804321289, 'total_steps': 201, 'train_mean_token_accuracy': 0.9230769276618958}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-0j9FpsV1ApoCH2yWrqHvxyYz', created_at=1732811340, level='info', message='Step 112/201: training loss=0.00', object='fine_tuning.job.event', data={'step': 112, 'train_loss': 0.0029439192730933428, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-JWEY9qOqq1mFkmCvjz0lY2DR', created_at=1732811340, level='info', message='Step 111/201: training loss=0.08', object='fine_tuning.job.event', data={'step': 111, 'train_loss': 0.07782341539859772, 'total_steps': 201, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-xEf0NWsd0F30u5jasq5caoH1', created_at=1732811339, level='info', message='Step 110/201: training loss=0.22', object='fine_tuning.job.event', data={'step': 110, 'train_loss': 0.21808727085590363, 'total_steps': 201, 'train_mean_token_accuracy': 0.8846153616905212}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-3lrKFbhbFLVOyCIMYkjclr3w', created_at=1732811339, level='info', message='Step 109/201: training loss=0.52', object='fine_tuning.job.event', data={'step': 109, 'train_loss': 0.520496129989624, 'total_steps': 201, 'train_mean_token_accuracy': 0.8799999952316284}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-ny0WgTXRMBembxXYtTjU2UWC', created_at=1732811336, level='info', message='Step 108/201: training loss=0.11', object='fine_tuning.job.event', data={'step': 108, 'train_loss': 0.10908479988574982, 'total_steps': 201, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-iroPYNfXWET4Kl1ZsvUmOG2h', created_at=1732811336, level='info', message='Step 107/201: training loss=0.02', object='fine_tuning.job.event', data={'step': 107, 'train_loss': 0.02269241400063038, 'total_steps': 201, 'train_mean_token_accuracy': 1.0}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-y54wrhLjUXmmd4T4lwEaIoTA', created_at=1732811336, level='info', message='Step 106/201: training loss=0.07', object='fine_tuning.job.event', data={'step': 106, 'train_loss': 0.07477134466171265, 'total_steps': 201, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics')]

# %%
events = list(client.fine_tuning.jobs.list_events(fine_tuning_job_id=retrieve_job.id, limit = 100).data) #last 100 events

for e in events:
    print(e.message)
# Out:
# The job has successfully completed
# New fine-tuned model created
# Checkpoint created at step 134
# Checkpoint created at step 67
# Step 201/201: training loss=0.00
# Step 200/201: training loss=0.17
# Step 199/201: training loss=0.12
# Step 198/201: training loss=0.11
# Step 197/201: training loss=0.04
# Step 196/201: training loss=0.01
# Step 195/201: training loss=0.08
# Step 194/201: training loss=0.00
# Step 193/201: training loss=0.12
# Step 192/201: training loss=0.05
# Step 191/201: training loss=0.01
# Step 190/201: training loss=0.08
# Step 189/201: training loss=0.14
# Step 188/201: training loss=0.07
# Step 187/201: training loss=0.03
# Step 186/201: training loss=0.01
# Step 185/201: training loss=0.12
# Step 184/201: training loss=0.01
# Step 183/201: training loss=0.00
# Step 182/201: training loss=0.10
# Step 181/201: training loss=0.03
# Step 180/201: training loss=0.11
# Step 179/201: training loss=0.00
# Step 178/201: training loss=0.06
# Step 177/201: training loss=0.04
# Step 176/201: training loss=0.00
# Step 175/201: training loss=0.12
# Step 174/201: training loss=0.01
# Step 173/201: training loss=0.02
# Step 172/201: training loss=0.01
# Step 171/201: training loss=0.02
# Step 170/201: training loss=0.03
# Step 169/201: training loss=0.02
# Step 168/201: training loss=0.05
# Step 167/201: training loss=0.14
# Step 166/201: training loss=0.02
# Step 165/201: training loss=0.07
# Step 164/201: training loss=0.16
# Step 163/201: training loss=0.03
# Step 162/201: training loss=0.04
# Step 161/201: training loss=0.03
# Step 160/201: training loss=0.08
# Step 159/201: training loss=0.05
# Step 158/201: training loss=0.01
# Step 157/201: training loss=0.06
# Step 156/201: training loss=0.03
# Step 155/201: training loss=0.02
# Step 154/201: training loss=0.02
# Step 153/201: training loss=0.00
# Step 152/201: training loss=0.07
# Step 151/201: training loss=0.01
# Step 150/201: training loss=0.07
# Step 149/201: training loss=0.07
# Step 148/201: training loss=0.00
# Step 147/201: training loss=0.21
# Step 146/201: training loss=0.00
# Step 145/201: training loss=0.10
# Step 144/201: training loss=0.02
# Step 143/201: training loss=0.12
# Step 142/201: training loss=0.03
# Step 141/201: training loss=0.08
# Step 140/201: training loss=0.04
# Step 139/201: training loss=0.03
# Step 138/201: training loss=0.04
# Step 137/201: training loss=0.05
# Step 136/201: training loss=0.00
# Step 135/201: training loss=0.05
# Step 134/201: training loss=0.17
# Step 133/201: training loss=0.05
# Step 132/201: training loss=0.03
# Step 131/201: training loss=0.04
# Step 130/201: training loss=0.05
# Step 129/201: training loss=0.05
# Step 128/201: training loss=0.06
# Step 127/201: training loss=0.15
# Step 126/201: training loss=0.09
# Step 125/201: training loss=0.08
# Step 124/201: training loss=0.00
# Step 123/201: training loss=0.00
# Step 122/201: training loss=0.06
# Step 121/201: training loss=0.02
# Step 120/201: training loss=0.04
# Step 119/201: training loss=0.09
# Step 118/201: training loss=0.09
# Step 117/201: training loss=0.11
# Step 116/201: training loss=0.00
# Step 115/201: training loss=0.03
# Step 114/201: training loss=0.06
# Step 113/201: training loss=0.13
# Step 112/201: training loss=0.00
# Step 111/201: training loss=0.08
# Step 110/201: training loss=0.22
# Step 109/201: training loss=0.52
# Step 108/201: training loss=0.11
# Step 107/201: training loss=0.02
# Step 106/201: training loss=0.07

# %% [markdown]
# Let's extract the training loss in each learning step

# %%
steps = []
train_loss = []

for e in events:
    if (e.data):
        steps.append(e.data['step'])
        train_loss.append(e.data['train_loss'])

# %% [markdown]
# Use a line chart to visualize the train_loss in each step

# %%
plt.plot(steps, train_loss, marker="o", linestyle= "-")

# %% [markdown]
# ### Task 5 - Deploy our model

# %% [markdown]
# Let's take a look at `retrieved_job` again

# %%
retrieve_job
# Out:
# FineTuningJob(id='ftjob-sC8rpU5j9nyOltsZfbSEjBMR', created_at=1732811047, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-mini-2024-07-18:personal::AYbigjHR', finished_at=1732811508, hyperparameters=Hyperparameters(n_epochs=3, batch_size=1, learning_rate_multiplier=1.8), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-Lqzv96QnFH3JDxxzx5j84wxT', result_files=['file-A9LkFQaNfm89zQj9xqqJLb'], seed=317319951, status='succeeded', trained_tokens=27015, training_file='file-5nJQLXozQP12N5tiRrdBoe', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix=None)

# %%
fine_tuned_model = retrieve_job.fine_tuned_model
fine_tuned_model
# Out:
# 'ft:gpt-4o-mini-2024-07-18:personal::AYbigjHR'

# %% [markdown]
# Defining a method to extract information from a given user complaint using a specific LLM and return the results.

# %%
def extract_details(user_complaint, model_name):
    """
    This function extracts information from a given user complaint using a specific LLM (Large Language Model).

    Parameters:
    user_complaint (str): The text of the user's complaint.
    model_name (str): The name of the specific LLM model to use for extraction.
    """

    system_content = """
        Given a customer complaint text, extract and return the following information in JSON (dict) format:
        - Topic
        - Problem
        - Customer_Dissatisfaction_Index
    """

    # Generate a response using the specified model and the user's complaint
    response = client.chat.completions.create(
        model = model_name,
        messages=[
            {"role": "system", "content": system_content},  # System content explaining the expected output
            {"role": "user", "content": user_complaint}  # User's complaint passed as content
        ]
    )

    # Return the content of the generated response
    return response.choices[0].message.content

# %% [markdown]
# Let's use our fine-tuned model to extract the details for the following user complaint:
#
# *TV channels keep disappearing from my subscription! What's going on? Extremely annoyed with this service!*

# %%
complaint = "TV channels keep disappearing from my subscription! What's going on? Extremely annoyed with this service!"

extract_details(complaint, fine_tuned_model)
# Out:
# '{"Topic": "TV", "Problem": "Channels disappearing", "Customer_Dissatisfaction_Index": 8}'

# %% [markdown]
# Let's test our `GPT-4` model with the same user complaint

# %%
model = "gpt-4o-mini-2024-07-18"

extract_details(complaint, model)
# Out:
# '{\n    "Topic": "TV Service",\n    "Problem": "Disappearing TV channels from subscription",\n    "Customer_Dissatisfaction_Index": 9\n}'

# %% [markdown]
# Let's try for the following complaint:
#
# *Line is down! It is really annoying!*

# %%
complaint = "Line is down! It is really annoying!"

extract_details(complaint, fine_tuned_model)
# Out:
# '{"Topic": "Internet", "Problem": "Line down", "Customer_Dissatisfaction_Index": 9}'

# %% [markdown]
# Now let's compare the results from GPT-4

# %%
extract_details(complaint, model)
# Out:
# '{\n    "Topic": "Service Interruption",\n    "Problem": "Line is down",\n    "Customer_Dissatisfaction_Index": 8\n}'

# %% [markdown]
# We can see that our model, which is trained on our dataset, provides better answers compared to GPT-4. Our model is fine-tuned based on our data and is familiar with the different edge cases and the context of our dataset.

# %%
customer_complaint = "I am very Angry! I want my money back!"

extract_details(customer_complaint, fine_tuned_model)
# Out:
# '{"Topic": "Billing", "Problem": "Refund request", "Customer_Dissatisfaction_Index": 9}'
