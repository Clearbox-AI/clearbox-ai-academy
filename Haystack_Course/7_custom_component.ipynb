# %% [markdown]
# ## Custom Components

# %%
import warnings
import os
warnings.filterwarnings('ignore')

from dotenv import load_dotenv

load_dotenv()

#HF_API_TOKEN = os.getenv("HF_API_TOKEN")
OPENAI_API_TOKEN = os.getenv("OPENAI_API_TOKEN")

# %%
import requests

from typing import List

from haystack import Document, Pipeline, component
from haystack.components.builders import PromptBuilder
from haystack.components.generators.openai import OpenAIGenerator
from haystack.utils import Secret

# %% [markdown]
# ## Custom Component Requirements
# Requirements
# Here are the requirements for all custom components:
#
# - **@component**: This decorator marks a class as a component, allowing it to be used in a pipeline.
# - **run()**: This is a required method in every component. It accepts input arguments and returns a dict. The inputs can either come from the pipeline when it’s executed, or from the output of another component when connected using connect(). The run() method should be compatible with the input/output definitions declared for the component.
#
#
# ** A decorator in Python is a function that allows you to extend or modify the behavior of another function or method without directly changing its source code. Decorators are particularly useful when you want to apply the same behavior to multiple functions or classes without duplicating code.
#
# #### Build a Custom Component

# %%
@component
class Greeter:

    # The following decorator defines the output types and names at the time of class definition.
    # The output names and types must match the dict returned by the run() method. 
    @component.output_types(greeting=str)
    def run(self, user_name: str):
        return {"greeting": f"Hello {user_name}"}

# %% [markdown]
# #### Run the Component

# %%
greeter = Greeter()

greeter.run(user_name="Simona")
# Out:
# {'greeting': 'Hello Simona'}

# %% [markdown]
# #### Add the Component to a Pipeline

# %%
greeter = Greeter()
template = """ You will be given the beginning of a dialogue. 
Create a short play script using this as the start of the play.
Start of dialogue: {{ dialogue }}
Full script: 
"""
prompt = PromptBuilder(template=template)
llm = OpenAIGenerator(api_key=Secret.from_token(OPENAI_API_TOKEN))

dialogue_builder = Pipeline()
dialogue_builder.add_component("greeter", greeter)
dialogue_builder.add_component("prompt", prompt)
dialogue_builder.add_component("llm", llm)

dialogue_builder.connect("greeter.greeting", "prompt.dialogue")
dialogue_builder.connect("prompt", "llm")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x0000015CBA877590>
# 🚅 Components
#   - greeter: Greeter
#   - prompt: PromptBuilder
#   - llm: OpenAIGenerator
# 🛤️ Connections
#   - greeter.greeting -> prompt.dialogue (str)
#   - prompt.prompt -> llm.prompt (str)

# %%
dialogue_builder.show()

# %%
dialogue = dialogue_builder.run({"greeter": {"user_name": "Simona"}})

print(dialogue["llm"]["replies"][0])
# Out:
# **Title: A Cup of Change**
#
# **Setting: A cozy café with warm lighting. A few patrons are scattered at tables, sipping coffee and chatting. The sound of a steaming espresso machine fills the air.**
#
# ---
#
# **Characters:**
#
# - **JAMES:** A warm-hearted, slightly awkward man in his early thirties.
# - **SIMONA:** A confident woman in her late twenties, with an adventurous spirit.
#
# ---
#
# **(Scene opens with JAMES standing at the counter, nervously waiting for his order. SIMONA, sitting at a nearby table, catches his eye and smiles.)**
#
# **SIMONA:** (cheerfully) Hello, Simona!
#
# **JAMES:** (startled, then smiles back) Oh! Uh, hi! I didn’t expect—
#
# **SIMONA:** (interrupts) It’s good to see you again, James. How’s life treating you?
#
# **JAMES:** (fidgeting) Pretty good, I guess. Just the usual grind. Work took over my life again.
#
# **SIMONA:** (leans forward) You’ve got to find time for yourself! What happened to that adventurous spirit I saw last time?
#
# **JAMES:** (chuckles nervously) It got buried under spreadsheets and emails, sadly.
#
# **SIMONA:** (playfully) You know, I think I can help with that. What if we make a pact? No work talk during coffee breaks!
#
# **JAMES:** (raises an eyebrow) A pact?
#
# **SIMONA:** (dramatically) Yes! A life-changing, cup-of-coffee pact! We can explore life outside of work.
#
# **JAMES:** (hesitating) I don’t know, Simona. It’s easier said than done…
#
# **SIMONA:** (persistent) Come on! What’s the worst that can happen? You might just rediscover the fun in your life!
#
# **JAMES:** (smiling) Okay, you have a point. I just…
#
# **SIMONA:** (cuts in) Just what?
#
# **JAMES:** (sighs) I guess I’m just afraid I won’t measure up to your adventures. You’re always doing something exciting!
#
# **SIMONA:** (laughs) Trust me, I have my fair share of clumsy moments. Remember when I tried rock climbing and got stuck halfway up?
#
# **(They both laugh, breaking the tension.)**
#
# **JAMES:** Okay, fair enough. So, what’s on the agenda for this ‘adventurous pact’?
#
# **SIMONA:** (brightening) How about a weekend trip? Just a quick getaway. We’ll find a hiking trail and get some fresh air.
#
# **JAMES:** (pondering) A hiking trip… I haven’t done that in years.
#
# **SIMONA:** (nudges him playfully) It'll be fun! We can take pictures, maybe get lost a little— make a whole adventure out of it!
#
# **JAMES:** (smiling) You really make this sound tempting. I could use a change of scenery.
#
# **SIMONA:** (grinning) Great! It’s a plan then! When are you free?
#
# **JAMES:** (looks at his phone) This weekend looks good. Let me just double-check my schedule…
#
# **(He fiddles with his phone, and SIMONA sips her coffee, looking excited.)**
#
# **SIMONA:** (teasing) If you cancel on me, I’ll come to your office and drag you out myself!
#
# **JAMES:** (laughing) Well, that would be a sight to see!
#
# **(A beat. JAMES glances at her, his expression more serious.)**
#
# **JAMES:** You know, I really appreciate this. It’s been a while since I felt like I could enjoy life again.
#
# **SIMONA:** (softly) That’s what friends are for. No more ‘just doing the grind,’ okay?
#
# **JAMES:** (nods) Okay. No more grinding— just living.
#
# **(A pause before they both smile widely.)**
#
# **SIMONA:** Pact made! Now... what do you want to order?
#
# **(JAMES looks up at the menu, a playful spark in his eye.)**
#
# **JAMES:** How about a large adventure latte?
#
# **SIMONA:** (grinning) Perfect choice! One adventure latte coming right up!
#
# **(They both laugh and the scene fades out as they continue to talk.)**
#
# ---
#
# **(End of Play)**

# %%
import logging

logging.basicConfig(format="%(levelname)s - %(name)s -  %(message)s", level=logging.WARNING)
logging.getLogger("haystack").setLevel(logging.INFO)
